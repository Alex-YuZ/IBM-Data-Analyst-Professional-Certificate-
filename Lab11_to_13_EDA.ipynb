# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Identify the distribution of data in the dataset.
#
# *   Identify outliers in the dataset.
#
# *   Remove outliers from the dataset.
#
# *   Identify correlation between features in the dataset.

# %% [markdown]
# ***

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11398 entries, 0 to 11397
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              11398 non-null  int64
#  1   MainBranch              11398 non-null  object
#  2   Hobbyist                11398 non-null  object
#  3   OpenSourcer             11398 non-null  object
#  4   OpenSource              11317 non-null  object
#  5   Employment              11398 non-null  object
#  6   Country                 11398 non-null  object
#  7   Student                 11347 non-null  object
#  8   EdLevel                 11286 non-null  object
#  9   UndergradMajor          10661 non-null  object
#  10  EduOther                11234 non-null  object
#  11  OrgSize                 11302 non-null  object
#  12  DevType                 11333 non-null  object
#  13  YearsCode               11389 non-null  object
# ...

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
# your code goes here
# plt.figure(figsize=(12, 6))
fig, ax = plt.subplots(figsize=(12, 6))
sns.kdeplot(df.ConvertedComp, ax=ax)
ax.spines['top'].set_visible(None)
ax.spines['right'].set_visible(None)
plt.title("Converted Compensation Distribution Curve among Respondents", fontsize=18, fontweight='bold', pad=20)
plt.xticks(fontsize=12)
plt.xlabel('Converted Compensation', fontsize=14, labelpad=12)
plt.ylabel('Density', fontsize=14, labelpad=12);

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here
sns.displot(df.ConvertedComp, height=6, aspect=2)
plt.title("Converted Compensation Distribution among Respondents", fontsize=18, fontweight='bold', pad=20)
plt.xticks(fontsize=12)
plt.xlabel('Converted Compensation', fontsize=14, labelpad=12)
plt.ylabel('Count', fontsize=14, labelpad=12);

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
df.ConvertedComp.median()
# Out:
# 57745.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here
df.Gender.value_counts()
# Out:
# Man                                                            10480
# Woman                                                            731
# Non-binary, genderqueer, or gender non-conforming                 63
# Man;Non-binary, genderqueer, or gender non-conforming             26
# Woman;Non-binary, genderqueer, or gender non-conforming           14
# Woman;Man                                                          9
# Woman;Man;Non-binary, genderqueer, or gender non-conforming        2
# Name: Gender, dtype: int64

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here
df[df.Gender=='Woman'].ConvertedComp.median()
# Out:
# 57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
df.Age.describe()
# Out:
# count    11111.000000
# mean        30.778895
# std          7.393686
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %%
df.Age.isna().sum()
# Out:
# 287

# %%
np.nanpercentile(np.array(df.Age), q=[25, 75])
# Out:
# array([25., 35.])

# %%
# your code goes here
min_age = df.Age.min()
max_age = df.Age.max()
median_age = df.Age.median()
q1_age = np.nanpercentile(np.array(df.Age), 25)
q3_age = np.nanpercentile(np.array(df.Age), 75)
print("Minimum age: {}\n1st quantile age: {}\nMedian age: {}\n3rd quantile age: {}\nMaximum age: {}".format(min_age, q1_age, median_age, q3_age, max_age))
# Out:
# Minimum age: 16.0
# 1st quantile age: 25.0
# Median age: 29.0
# 3rd quantile age: 35.0
# Maximum age: 99.0

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here
sns.displot(df.Age, height=6, aspect=2.5, bins=40)
plt.title("Age Distribution among Respondents", fontsize=18, fontweight='bold', pad=20)
plt.xticks(range(0, 100, 2), fontsize=12)
plt.xlabel('Age', fontsize=14, labelpad=12)
plt.ylabel('Count', fontsize=14, labelpad=12);

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here
fig, ax = plt.subplots(figsize=(14,6))
sns.boxplot(x=df.ConvertedComp, ax=ax)
plt.title("Converted Compensation Distribution using Boxplot", pad=20, fontsize=18, fontweight='bold')
plt.xticks(fontsize=12)
plt.ylabel('Converted Compensation', fontsize=14, labelpad=12)
plt.xlabel('Values ($)', fontsize=14, labelpad=12);

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here
q1, q3 = np.nanpercentile(df.ConvertedComp, [25, 75])
q_range = q3 - q1
q_range
# Out:
# 73132.0

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here
lower_bound = df.ConvertedComp.min()
upper_bound = df.ConvertedComp.max()
print("Lower Bound: {}\nUpper Bound: {}".format(lower_bound, upper_bound))
# Out:
# Lower Bound: 0.0
# Upper Bound: 2000000.0

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here
max_limit = q3 + 1.5*q_range
min_limit = q1 - 1.5*q_range
max_limit, min_limit
# Out:
# (209698.0, -82830.0)

# %%
count_low_outlier = df.ConvertedComp.lt(min_limit).sum()
count_high_outlier = df.ConvertedComp.gt(max_limit).sum()
print("Total count of outliers is: {}".format(count_high_outlier+count_low_outlier))
# Out:
# Total count of outliers is: 879

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
df.shape
# Out:
# (11398, 85)

# %%
df[(df.ConvertedComp>=max_limit)].shape
# Out:
# (879, 85)

# %%
df[(df.ConvertedComp<=min_limit)].shape
# Out:
# (0, 85)

# %%
# Filter out outliers in ConvertedComp
df1 = df[(df.ConvertedComp>=min_limit) & (df.ConvertedComp<=max_limit)]
df1.shape
# Out:
# (9703, 85)

# %%
# Before removing outliers
df.ConvertedComp.describe().apply(lambda s: format(s, 'f'))
# Out:
# count      10582.000000
# mean      131596.731620
# std       294786.515775
# min            0.000000
# 25%        26868.000000
# 50%        57745.000000
# 75%       100000.000000
# max      2000000.000000
# Name: ConvertedComp, dtype: object

# %%
# After removing outliers
df1.ConvertedComp.describe()
# Out:
# count      9703.000000
# mean      59883.208389
# std       43394.336755
# min           0.000000
# 25%       24060.000000
# 50%       52704.000000
# 75%       85574.500000
# max      209356.000000
# Name: ConvertedComp, dtype: float64

# %%
# Why 9703? Because there are na values
df.ConvertedComp.isna().sum()
# Out:
# 816

# %%
11398-879-816
# Out:
# 9703

# %%
# Boxplot of `Age`
fig, ax = plt.subplots(figsize=(14,6))
sns.boxplot(x=df.Age, ax=ax)
plt.title("Age Distribution using Boxplot", pad=20, fontsize=18, fontweight='bold')
plt.xticks(fontsize=12)
plt.ylabel('Age', fontsize=14, labelpad=12)
plt.xlabel('Values (y/o)', fontsize=14, labelpad=12);

# %%
df.Age.describe()
# Out:
# count    11111.000000
# mean        30.778895
# std          7.393686
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here
df1.corr()
# Out:
#                Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs  \
# Respondent       1.000000  -0.019354       0.010878    -0.016221    0.005293
# CompTotal       -0.019354   1.000000      -0.063561     0.004910    0.017007
# ConvertedComp    0.010878  -0.063561       1.000000     0.034351   -0.088934
# WorkWeekHrs     -0.016221   0.004910       0.034351     1.000000    0.038935
# CodeRevHrs       0.005293   0.017007      -0.088934     0.038935    1.000000
# Age              0.002180   0.006337       0.401821     0.032032   -0.012878
#
#                     Age
# Respondent     0.002180
# CompTotal      0.006337
# ConvertedComp  0.401821
# WorkWeekHrs    0.032032
# CodeRevHrs    -0.012878
# Age            1.000000

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(df1.corr(), annot=True, square=True, ax=ax, annot_kws={'fontsize': 14})

plt.title("Variable Correlation Heatmap", fontsize=18, fontweight='bold', pad=50)
plt.xticks(fontsize=18, rotation=30, ha='right')
plt.yticks(fontsize=18);

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer\&utm_source=Exinfluencer\&utm_content=000026UJ\&utm_term=10006555\&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01\&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264\&cm_mmca1=000026UJ\&cm_mmca2=10006555\&cm_mmca3=M12345678\&cvosrc=email.Newsletter.M12345678\&cvo_campaign=000026UJ).
